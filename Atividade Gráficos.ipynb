# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# #### Exercicio 1

# %%
x = np.linspace(1, 20, 100)
y = x**2
plt.plot(x,y, c='g')
plt.title("Teste de Plotagem")
plt.grid()

# %% [markdown]
# #### Exercicio 2

# %%
ts = pd.Series(y)
ts.plot(grid=True, c='g')
plt.title("Teste de Plotagem")
# Out:
# Text(0.5, 1.0, 'Teste de Plotagem')

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000)).cumsum()
ts
# Out:
# 2000-01-01     0.233579
# 2000-01-02     0.609124
# 2000-01-03     1.390993
# 2000-01-04    -0.456191
# 2000-01-05    -0.439016
# 2000-01-06    -2.331358
# 2000-01-07    -3.647408
# 2000-01-08    -5.035914
# 2000-01-09    -3.387491
# 2000-01-10    -3.446696
# 2000-01-11    -2.182684
# 2000-01-12    -2.701945
# 2000-01-13    -3.466624
# 2000-01-14    -3.036797
# 2000-01-15    -2.409994
# 2000-01-16    -2.632059
# 2000-01-17    -4.288076
# 2000-01-18    -5.739601
# 2000-01-19    -5.044275
# 2000-01-20    -3.845581
# 2000-01-21    -5.563625
# 2000-01-22    -5.778646
# 2000-01-23    -5.737413
# 2000-01-24    -4.809657
# 2000-01-25    -6.238011
# 2000-01-26    -8.312767
# 2000-01-27    -6.140090
# 2000-01-28    -5.955462
# 2000-01-29    -5.353038
# 2000-01-30    -4.788004
#                 ...
# 2002-08-28   -40.119474
# 2002-08-29   -38.562567
# 2002-08-30   -38.783351
# 2002-08-31   -38.914884
# 2002-09-01   -37.826877
# 2002-09-02   -38.331926
# 2002-09-03   -36.891495
# ...

# %%
ts.plot()
plt.title('teste de Plotagem')
plt.grid()
plt.show()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), 
                  index=ts.index, columns=list('ABCD')).cumsum()
df.plot()
plt.title('teste de Plotagem')
# Out:
# Text(0.5, 1.0, 'teste de Plotagem')

# %%
var = pd.Series(['Rock', 'Paper', 'Rock',
                 'Scissor', 'Scissor', 'Paper',
                 'Paper', 'Scissor', 'Scissor'])
var
# Out:
# 0       Rock
# 1      Paper
# 2       Rock
# 3    Scissor
# 4    Scissor
# 5      Paper
# 6      Paper
# 7    Scissor
# 8    Scissor
# dtype: object

# %%
a = var.value_counts()
a
# Out:
# Scissor    4
# Paper      3
# Rock       2
# dtype: int64

# %%
var.value_counts(normalize=True)*100
# Out:
# Scissor    44.444444
# Paper      33.333333
# Rock       22.222222
# dtype: float64

# %%
a.plot.pie(figsize=(6, 6))
plt.title("Faltou Spock")
# Out:
# Text(0.5, 1.0, 'Faltou Spock')

# %% [markdown]
# #### Exercicio 3

# %% [markdown]
# R. Grafico pizza não suporta valores em strings

# %%
planeta = pd.DataFrame({'massa': [0.330, 4.87 , 5.97],
                   'raio': [2439.7, 6051.8, 6378.1]},
                   index=['Mercúrio', 'Vênus', 'Terra'])
planeta
# Out:
#           massa    raio
# Mercúrio   0.33  2439.7
# Vênus      4.87  6051.8
# Terra      5.97  6378.1

# %%
planeta.plot.pie(y='massa', figsize=(5, 5))

# %%
planeta.plot.pie(figsize=(10, 5), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000171EE969C88>,
# ...
#       dtype=object)

# %% [markdown]
# #### Exercicio 4

# %% [markdown]
# R. Sim. como no exemplo acima, é só passar "subplots" sendo com TRUE, ele vai pegar todos as colunas e fazer os graficos separadamente.

# %% [markdown]
# #### Exercicio 5

# %% [markdown]
# R. É um grafico mais visual, no qual busca uma interpretação mais fácil. a desvantagem seria a precisão para analisar tais dados, se faz visivel quando analisamos um conjunto grande de dados, onde se trabalha com multiplas variaveis.

# %%
circulo=plt.Circle( (0,0), 0.7, color='white')

# %%
planeta.plot.pie(y='massa', figsize=(5, 5))
p=plt.gcf()
p.gca().add_artist(circulo)

# %% [markdown]
# #### Exercicio 6

# %%
df = pd.DataFrame({'massa': [5.97, 4.87, 0.330],
                   'raio': [6378.1, 6051.8, 2439.7]},
                   index=['Mercúrio', 'Vênus', 'Terra'])

# %%
colors = ['#ff9999','#66b3ff','#99ff99']
labels = ['Vênus', 'Terra', 'Mercúrio']

# %%
df.plot.pie(y='massa', figsize=(5, 5), colors=colors, labels=labels)

# %%
df = pd.DataFrame({'velocidade': [0.1, 17.5, 40, 48, 52, 69, 88], 
                   'tempo de vida': [2, 8, 70, 1.5, 25, 12, 28]}, 
                   index=['caracol', 'porco', 'elefante', 'coelho', 'girafa', 'coiote', 'cavalo'])
df
# Out:
#           velocidade  tempo de vida
# caracol          0.1            2.0
# porco           17.5            8.0
# elefante        40.0           70.0
# coelho          48.0            1.5
# girafa          52.0           25.0
# coiote          69.0           12.0
# cavalo          88.0           28.0

# %%
df['velocidade'].plot.bar()
plt.grid(c='g', ls=':')

# %% [markdown]
# #### Exercicio 7

# %%
df['velocidade'].plot.pie(figsize=(6, 6), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000171EEB7F048>],
#       dtype=object)

# %% [markdown]
# R. Se compararmos os gráficos acima, constatamos que, o de barras tem mais precisão, visto que o de setores só vai dar uma noção de proporção.

# %%
df['velocidade'].plot.barh()
plt.grid(c='g', ls=':')
plt.title("Teste de Plotagem")
# Out:
# Text(0.5, 1.0, 'Teste de Plotagem')

# %%
df.plot.bar(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000171EEB7FA20>,
# ...
#       dtype=object)

# %% [markdown]
# #### Exercicio 8

# %%
df.plot.bar(x='tempo de vida', y='velocidade')

# %% [markdown]
# R. se mudarmos x e y, o y se torna o eixo das ordenadas, e o x o das abcissas.

# %%
df.plot.bar(x='velocidade', y='tempo de vida' )

# %%
df.plot.bar()

# %%
df.plot.barh()

# %%
df.plot.bar(stacked=True)

# %% [markdown]
# #### Exercicio 9

# %%
df.plot.barh(stacked=True)

# %%
df2 = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000),
                    'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

# %%
df2.plot.hist(bins=10)

# %%
df2['a'].plot.hist(bins=10)

# %%
df2['a'].plot.hist(bins=100, grid=True)

# %% [markdown]
# #### Exercicio 10

# %% [markdown]
# R. Frequencia de valores, nas colunas.

# %% [markdown]
# #### Exercicio 11

# %%
df2['a'].plot.hist(bins=4)

# %%
df2['a'].plot.hist(bins=1000)

# %%
df2.plot.kde()

# %% [markdown]
# #### Exercicio 12

# %%
ax = sns.distplot(df2['a'])

# %% [markdown]
# #### Exercicio 13

# %%
df3 = pd.read_csv('https://raw.githubusercontent.com/pcsanwald/kaggle-titanic/master/train.csv')
df3
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# 6           0       1                            McCarthy, Mr. Timothy J
# 7           0       3                     Palsson, Master. Gosta Leonard
# 8           1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# ...

# %%
df3.plot()

# %%
df3.plot.bar()

# %%
df3.plot.barh()

# %%
df3['survived'].value_counts().plot.pie()
plt.title("Sobreviventes")
# Out:
# Text(0.5, 1.0, 'Sobreviventes')
